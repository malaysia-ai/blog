# %% [markdown]
# # Twitter and local news data in Malaysia-AI Elasticsearch

# %% [markdown]
# As you know, Malaysia-AI got a cloud ElasticSearch, protected by Github Auth at https://elasticsearch.malaysiaai.ml/, and recently we deployed Tweepy streaming and local news crawler at https://github.com/malaysia-ai/crawlers. If you are member of Malaysia-AI, you should able to access that repository.

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search
from pycookiecheat import chrome_cookies
import requests

# %% [markdown]
# ## ElasticSearch
#
# To access ElasticSearch from anywhere,
#
# 1. Install dependencies,
#
# ```bash
# pip3 install requests pycookiecheat elasticsearch elasticsearch-dsl
# ```
#
# 2. You need to login https://elasticsearch.malaysiaai.ml using your Chrome.
#
# 3. Get the cookies.
#
# Or you can use any library that can fetch cookies from your browser, like, https://github.com/borisbabic/browser_cookie3

# %%
url = 'https://elasticsearch.malaysiaai.ml'
cookies = chrome_cookies(url)

# %%
requests.get(url, cookies = cookies).json()
# Out:
# {'name': 'huseincomel-desktop',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'WLWwNUhcTAaU7BGpsKwNkA',
#  'version': {'number': '7.17.0',
#   'build_flavor': 'default',
#   'build_type': 'deb',
#   'build_hash': 'bee86328705acaa9a6daede7140defd4d9ec56bd',
#   'build_date': '2022-01-28T08:36:04.875279988Z',
#   'build_snapshot': False,
#   'lucene_version': '8.11.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %% [markdown]
# If you are using https://jupyterhub.malaysiaai.ml/, ElasticSearch available at http://localhost:9200

# %% [markdown]
# ## Twitter
#
# Simply query https://elasticsearch.malaysiaai.ml/twitter_streaming/_search

# %%
query = {
    'size': 2
}
url = 'https://elasticsearch.malaysiaai.ml/twitter_streaming/_search'
requests.get(url, cookies = cookies, json = query).json()
# Out:
# {'took': 604,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'twitter_streaming',
#     '_type': '_doc',
#     '_id': 'tRasQIABg_n2UR6_-kBI',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-04-19T07:11:51',
#      'datetime_gmt8': '2022-04-19T15:11:51',
#      'data_text': 'he can defeat thanos https://t.co/nIgaWoHkcT',
#      'body': 'RT @JMHlHl: he can defeat thanos https://t.co/nIgaWoHkcT',
#      'screen_name': 'xjuleenx',
#      'followers_count': 519,
#      'friends_count': 392,
#      'listed_count': 1,
#      'favourites_count': 27196,
#      'statuses_count': 119922,
#      'quoted_status_text': 'NULL',
#      'lang': 'en',
#      'retweet': 'true',
#      'retweet_text': 'he can defeat thanos https://t.co/nIgaWoHkcT',
#      'retweet_text_full': 'NULL',
#      'retweet_count': 0,
#      'retweet_detail': {'retweet_count': 543,
#       'quote_count': 23,
#       'favorite_count': 2396,
#       'reply_count': 9,
#       'id_str': '1516139448014352384',
#       'followers_count': 937,
#       'friends_count': 21,
#       'listed_count': 15,
#       'favourites_count': 336,
#       'statuses_count': 562,
#       'screen_name': 'JMHlHl'},
#      'quote_count': 0,
#      'favorite_count': 0,
#      'reply_count': 0,
#      'id_str': '1516313612645675010',
#      'tweet': {'created_at': 'Tue Apr 19 07:11:51 +0000 2022',
#       'id': 1516313612645675010,
#       'id_str': '1516313612645675010',
#       'text': 'RT @JMHlHl: he can defeat thanos https://t.co/nIgaWoHkcT',
#       'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#       'truncated': False,
#       'in_reply_to_status_id': None,
#       'in_reply_to_status_id_str': None,
#       'in_reply_to_user_id': None,
#       'in_reply_to_user_id_str': None,
#       'in_reply_to_screen_name': None,
#       'user': {'id': 287662914,
#        'id_str': '287662914',
#        'name': 'juleen⁷ ∞ 💜',
#        'screen_name': 'xjuleenx',
#        'location': "taehyung's heart ♡",
#        'url': None,
#        'description': '🇸🇬 ♡ 7 boys- okay nvm lets make it 19 boys making my life perfect ♡ \n∞ BTS/ TXT/ ENHYPEN ∞',
#        'translator_type': 'none',
#        'protected': False,
#        'verified': False,
#        'followers_count': 519,
#        'friends_count': 392,
#        'listed_count': 1,
#        'favourites_count': 27196,
#        'statuses_count': 119922,
#        'created_at': 'Mon Apr 25 12:53:24 +0000 2011',
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': False,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'profile_background_color': 'FF6699',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#        'profile_background_tile': True,
#        'profile_link_color': 'B40B43',
#        'profile_sidebar_border_color': 'CC3366',
#        'profile_sidebar_fill_color': 'E5507E',
#        'profile_text_color': '362720',
#        'profile_use_background_image': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1515659085580214272/KuWvSRGA_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1515659085580214272/KuWvSRGA_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/287662914/1650196224',
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': None,
#        'follow_request_sent': None,
#        'notifications': None,
#        'withheld_in_countries': []},
#       'geo': None,
#       'coordinates': None,
#       'place': None,
#       'contributors': None,
#       'retweeted_status': {'created_at': 'Mon Apr 18 19:39:47 +0000 2022',
#        'id': 1516139448014352384,
#        'id_str': '1516139448014352384',
#        'text': 'he can defeat thanos https://t.co/nIgaWoHkcT',
#        'display_text_range': [0, 20],
#        'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        'truncated': False,
#        'in_reply_to_status_id': None,
#        'in_reply_to_status_id_str': None,
#        'in_reply_to_user_id': None,
#        'in_reply_to_user_id_str': None,
#        'in_reply_to_screen_name': None,
#        'user': {'id': 1414262127519358980,
#         'id_str': '1414262127519358980',
#         'name': 'j.mㅎㅎ',
#         'screen_name': 'JMHlHl',
#         'location': 'she • her • anna',
#         'url': None,
#         'description': "jimimhihi's non-gigglz (side acc) || @meonjmi (let's be friends)",
#         'translator_type': 'none',
#         'protected': False,
#         'verified': False,
#         'followers_count': 937,
#         'friends_count': 21,
#         'listed_count': 15,
#         'favourites_count': 336,
#         'statuses_count': 562,
#         'created_at': 'Sun Jul 11 16:35:52 +0000 2021',
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'profile_background_color': 'F5F8FA',
#         'profile_background_image_url': '',
#         'profile_background_image_url_https': '',
#         'profile_background_tile': False,
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1512506833843683328/lUAUA9Yi_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1512506833843683328/lUAUA9Yi_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1414262127519358980/1649444716',
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'withheld_in_countries': []},
#        'geo': None,
#        'coordinates': None,
#        'place': None,
#        'contributors': None,
#        'is_quote_status': False,
#        'quote_count': 23,
#        'reply_count': 9,
#        'retweet_count': 543,
#        'favorite_count': 2396,
#        'entities': {'hashtags': [],
#         'urls': [],
#         'user_mentions': [],
#         'symbols': [],
#         'media': [{'id': 1516139436035440641,
#           'id_str': '1516139436035440641',
#           'indices': [21, 44],
#           'media_url': 'http://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#           'url': 'https://t.co/nIgaWoHkcT',
#           'display_url': 'pic.twitter.com/nIgaWoHkcT',
#           'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#           'type': 'photo',
#           'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'medium': {'w': 288, 'h': 288, 'resize': 'fit'},
#            'small': {'w': 288, 'h': 288, 'resize': 'fit'},
#            'large': {'w': 288, 'h': 288, 'resize': 'fit'}}}]},
#        'extended_entities': {'media': [{'id': 1516139436035440641,
#           'id_str': '1516139436035440641',
#           'indices': [21, 44],
#           'media_url': 'http://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#           'url': 'https://t.co/nIgaWoHkcT',
#           'display_url': 'pic.twitter.com/nIgaWoHkcT',
#           'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#           'type': 'photo',
#           'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'medium': {'w': 288, 'h': 288, 'resize': 'fit'},
#            'small': {'w': 288, 'h': 288, 'resize': 'fit'},
#            'large': {'w': 288, 'h': 288, 'resize': 'fit'}}},
#          {'id': 1516139436031246336,
#           'id_str': '1516139436031246336',
#           'indices': [21, 44],
#           'media_url': 'http://pbs.twimg.com/media/FQpoyMKagAASoke.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQpoyMKagAASoke.jpg',
#           'url': 'https://t.co/nIgaWoHkcT',
#           'display_url': 'pic.twitter.com/nIgaWoHkcT',
#           'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#           'type': 'photo',
#           'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'small': {'w': 313, 'h': 313, 'resize': 'fit'},
#            'large': {'w': 313, 'h': 313, 'resize': 'fit'},
#            'medium': {'w': 313, 'h': 313, 'resize': 'fit'}}}]},
#        'favorited': False,
#        'retweeted': False,
#        'possibly_sensitive': False,
#        'filter_level': 'low',
#        'lang': 'en'},
#       'is_quote_status': False,
#       'quote_count': 0,
#       'reply_count': 0,
#       'retweet_count': 0,
#       'favorite_count': 0,
#       'entities': {'hashtags': [],
#        'urls': [],
#        'user_mentions': [{'screen_name': 'JMHlHl',
#          'name': 'j.mㅎㅎ',
#          'id': 1414262127519358980,
#          'id_str': '1414262127519358980',
#          'indices': [3, 10]}],
#        'symbols': [],
#        'media': [{'id': 1516139436035440641,
#          'id_str': '1516139436035440641',
#          'indices': [33, 56],
#          'media_url': 'http://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#          'url': 'https://t.co/nIgaWoHkcT',
#          'display_url': 'pic.twitter.com/nIgaWoHkcT',
#          'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'medium': {'w': 288, 'h': 288, 'resize': 'fit'},
#           'small': {'w': 288, 'h': 288, 'resize': 'fit'},
#           'large': {'w': 288, 'h': 288, 'resize': 'fit'}},
#          'source_status_id': 1516139448014352384,
#          'source_status_id_str': '1516139448014352384',
#          'source_user_id': 1414262127519358980,
#          'source_user_id_str': '1414262127519358980'}]},
#       'extended_entities': {'media': [{'id': 1516139436035440641,
#          'id_str': '1516139436035440641',
#          'indices': [33, 56],
#          'media_url': 'http://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQpoyMLagAEwWlg.jpg',
#          'url': 'https://t.co/nIgaWoHkcT',
#          'display_url': 'pic.twitter.com/nIgaWoHkcT',
#          'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'medium': {'w': 288, 'h': 288, 'resize': 'fit'},
#           'small': {'w': 288, 'h': 288, 'resize': 'fit'},
#           'large': {'w': 288, 'h': 288, 'resize': 'fit'}},
#          'source_status_id': 1516139448014352384,
#          'source_status_id_str': '1516139448014352384',
#          'source_user_id': 1414262127519358980,
#          'source_user_id_str': '1414262127519358980'},
#         {'id': 1516139436031246336,
#          'id_str': '1516139436031246336',
#          'indices': [33, 56],
#          'media_url': 'http://pbs.twimg.com/media/FQpoyMKagAASoke.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQpoyMKagAASoke.jpg',
#          'url': 'https://t.co/nIgaWoHkcT',
#          'display_url': 'pic.twitter.com/nIgaWoHkcT',
#          'expanded_url': 'https://twitter.com/JMHlHl/status/1516139448014352384/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'small': {'w': 313, 'h': 313, 'resize': 'fit'},
#           'large': {'w': 313, 'h': 313, 'resize': 'fit'},
#           'medium': {'w': 313, 'h': 313, 'resize': 'fit'}},
#          'source_status_id': 1516139448014352384,
#          'source_status_id_str': '1516139448014352384',
#          'source_user_id': 1414262127519358980,
#          'source_user_id_str': '1414262127519358980'}]},
#       'favorited': False,
#       'retweeted': False,
#       'possibly_sensitive': False,
#       'filter_level': 'low',
#       'lang': 'en',
#       'timestamp_ms': '1650352311656',
#       'ignore_lang': True},
#      'type': 'search'}},
#    {'_index': 'twitter_streaming',
#     '_type': '_doc',
#     '_id': '_RatQIABg_n2UR6_aECY',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-04-19T07:14:46',
#      'datetime_gmt8': '2022-04-19T15:14:46',
#      'data_text': 'Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur katanya. Beliau kemalangan dalam perjalanan balik dari kerja di Hospital Temerloh. Selamat jalan Angah',
#      'body': 'RT @tunfairuz: Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur katanya. Bel',
#      'screen_name': 'nurrshahidahh',
#      'followers_count': 167,
#      'friends_count': 502,
#      'listed_count': 0,
#      'favourites_count': 29445,
#      'statuses_count': 40044,
#      'quoted_status_text': 'Walao weh. giler uncle ni msuk simpang secara melulu mcmtu jee sampai rider terpelanting. naya nyawa org weh. https://t.co/m6G4LFYOHL',
#      'lang': 'in',
#      'retweet': 'true',
#      'retweet_text': 'Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur kat https://t.co/0PWDpUGbPC',
#      'retweet_text_full': 'Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur katanya. Beliau kemalangan dalam perjalanan balik dari kerja di Hospital Temerloh. Selamat jalan Angah',
#      'retweet_count': 0,
#      'retweet_detail': {'retweet_count': 3771,
#       'quote_count': 59,
#       'favorite_count': 4206,
#       'reply_count': 83,
#       'id_str': '1516136632436477953',
#       'followers_count': 1685,
#       'friends_count': 293,
#       'listed_count': 1,
#       'favourites_count': 2577,
#       'statuses_count': 9510,
#       'screen_name': 'tunfairuz'},
#      'quote_count': 0,
#      'favorite_count': 0,
#      'reply_count': 0,
#      'id_str': '1516314345411858435',
#      'tweet': {'created_at': 'Tue Apr 19 07:14:46 +0000 2022',
#       'id': 1516314345411858435,
#       'id_str': '1516314345411858435',
#       'text': 'RT @tunfairuz: Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur katanya. Bel…',
#       'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#       'truncated': False,
#       'in_reply_to_status_id': None,
#       'in_reply_to_status_id_str': None,
#       'in_reply_to_user_id': None,
#       'in_reply_to_user_id_str': None,
#       'in_reply_to_screen_name': None,
#       'user': {'id': 1159446479926202368,
#        'id_str': '1159446479926202368',
#        'name': '.',
#        'screen_name': 'nurrshahidahh',
#        'location': 'Perak, Malaysia',
#        'url': None,
#        'description': '??????? idk what to do with my life now',
#        'translator_type': 'none',
#        'protected': False,
#        'verified': False,
#        'followers_count': 167,
#        'friends_count': 502,
#        'listed_count': 0,
#        'favourites_count': 29445,
#        'statuses_count': 40044,
#        'created_at': 'Thu Aug 08 12:49:17 +0000 2019',
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': False,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'profile_background_color': 'F5F8FA',
#        'profile_background_image_url': '',
#        'profile_background_image_url_https': '',
#        'profile_background_tile': False,
#        'profile_link_color': '1DA1F2',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1401136298279116803/GIziJcx5_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1401136298279116803/GIziJcx5_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1159446479926202368/1608479957',
#        'default_profile': True,
#        'default_profile_image': False,
#        'following': None,
#        'follow_request_sent': None,
#        'notifications': None,
#        'withheld_in_countries': []},
#       'geo': None,
#       'coordinates': None,
#       'place': None,
#       'contributors': None,
#       'retweeted_status': {'created_at': 'Mon Apr 18 19:28:36 +0000 2022',
#        'id': 1516136632436477953,
#        'id_str': '1516136632436477953',
#        'text': 'Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur kat… https://t.co/0PWDpUGbPC',
#        'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        'truncated': True,
#        'in_reply_to_status_id': None,
#        'in_reply_to_status_id_str': None,
#        'in_reply_to_user_id': None,
#        'in_reply_to_user_id_str': None,
#        'in_reply_to_screen_name': None,
#        'user': {'id': 777747875967086592,
#         'id_str': '777747875967086592',
#         'name': 'Dewi',
#         'screen_name': 'tunfairuz',
#         'location': 'Limburg an der Lahn',
#         'url': 'http://naratif.org',
#         'description': 'Memento mori | Goethe-Uni | 🇩🇪 | ABD',
#         'translator_type': 'none',
#         'protected': False,
#         'verified': False,
#         'followers_count': 1685,
#         'friends_count': 293,
#         'listed_count': 1,
#         'favourites_count': 2577,
#         'statuses_count': 9510,
#         'created_at': 'Mon Sep 19 05:55:18 +0000 2016',
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': True,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'profile_background_color': 'F5F8FA',
#         'profile_background_image_url': '',
#         'profile_background_image_url_https': '',
#         'profile_background_tile': False,
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1510899102862692353/d3oo3fqn_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1510899102862692353/d3oo3fqn_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/777747875967086592/1574770629',
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'withheld_in_countries': []},
#        'geo': None,
#        'coordinates': None,
#        'place': None,
#        'contributors': None,
#        'quoted_status_id': 1516004095584530435,
#        'quoted_status_id_str': '1516004095584530435',
#        'quoted_status': {'created_at': 'Mon Apr 18 10:41:57 +0000 2022',
#         'id': 1516004095584530435,
#         'id_str': '1516004095584530435',
#         'text': 'Walao weh. giler uncle ni msuk simpang secara melulu mcmtu jee sampai rider terpelanting. naya nyawa org weh. https://t.co/m6G4LFYOHL',
#         'display_text_range': [0, 109],
#         'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#         'truncated': False,
#         'in_reply_to_status_id': None,
#         'in_reply_to_status_id_str': None,
#         'in_reply_to_user_id': None,
#         'in_reply_to_user_id_str': None,
#         'in_reply_to_screen_name': None,
#         'user': {'id': 2905716522,
#          'id_str': '2905716522',
#          'name': 'ISU SEMASA VIRAL',
#          'screen_name': 'isusemasaviral',
#          'location': 'Kuala Lumpur City',
#          'url': None,
#          'description': None,
#          'translator_type': 'none',
#          'protected': False,
#          'verified': False,
#          'followers_count': 27161,
#          'friends_count': 3,
#          'listed_count': 24,
#          'favourites_count': 70,
#          'statuses_count': 11758,
#          'created_at': 'Fri Nov 21 05:37:21 +0000 2014',
#          'utc_offset': None,
#          'time_zone': None,
#          'geo_enabled': False,
#          'lang': None,
#          'contributors_enabled': False,
#          'is_translator': False,
#          'profile_background_color': 'C0DEED',
#          'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#          'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#          'profile_background_tile': False,
#          'profile_link_color': '1DA1F2',
#          'profile_sidebar_border_color': 'C0DEED',
#          'profile_sidebar_fill_color': 'DDEEF6',
#          'profile_text_color': '333333',
#          'profile_use_background_image': True,
#          'profile_image_url': 'http://pbs.twimg.com/profile_images/1506279361301082115/rj9vuCGJ_normal.jpg',
#          'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1506279361301082115/rj9vuCGJ_normal.jpg',
#          'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2905716522/1647920971',
#          'default_profile': True,
#          'default_profile_image': False,
#          'following': None,
#          'follow_request_sent': None,
#          'notifications': None,
#          'withheld_in_countries': []},
#         'geo': None,
#         'coordinates': None,
#         'place': None,
#         'contributors': None,
#         'is_quote_status': False,
#         'quote_count': 601,
#         'reply_count': 146,
#         'retweet_count': 3651,
#         'favorite_count': 4255,
#         'entities': {'hashtags': [],
#          'urls': [],
#          'user_mentions': [],
#          'symbols': [],
#          'media': [{'id': 1516004042249740288,
#            'id_str': '1516004042249740288',
#            'indices': [110, 133],
#            'additional_media_info': {'monetizable': False},
#            'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#            'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#            'url': 'https://t.co/m6G4LFYOHL',
#            'display_url': 'pic.twitter.com/m6G4LFYOHL',
#            'expanded_url': 'https://twitter.com/isusemasaviral/status/1516004095584530435/video/1',
#            'type': 'photo',
#            'sizes': {'large': {'w': 1272, 'h': 720, 'resize': 'fit'},
#             'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#             'medium': {'w': 1200, 'h': 679, 'resize': 'fit'},
#             'small': {'w': 680, 'h': 385, 'resize': 'fit'}}}]},
#         'extended_entities': {'media': [{'id': 1516004042249740288,
#            'id_str': '1516004042249740288',
#            'indices': [110, 133],
#            'additional_media_info': {'monetizable': False},
#            'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#            'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#            'url': 'https://t.co/m6G4LFYOHL',
#            'display_url': 'pic.twitter.com/m6G4LFYOHL',
#            'expanded_url': 'https://twitter.com/isusemasaviral/status/1516004095584530435/video/1',
#            'type': 'video',
#            'video_info': {'aspect_ratio': [53, 30],
#             'duration_millis': 29601,
#             'variants': [{'content_type': 'application/x-mpegURL',
#               'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/pl/nQhTA_ESF2IV1-tk.m3u8?tag=12&container=fmp4'},
#              {'bitrate': 256000,
#               'content_type': 'video/mp4',
#               'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/476x270/R3PD8Wlv5f_Qia7d.mp4?tag=12'},
#              {'bitrate': 2176000,
#               'content_type': 'video/mp4',
#               'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/1272x720/CF9niosUk6Bwv3dd.mp4?tag=12'},
#              {'bitrate': 832000,
#               'content_type': 'video/mp4',
#               'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/636x360/Pxqbs7kW_nJmmKTq.mp4?tag=12'}]},
#            'sizes': {'large': {'w': 1272, 'h': 720, 'resize': 'fit'},
#             'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#             'medium': {'w': 1200, 'h': 679, 'resize': 'fit'},
#             'small': {'w': 680, 'h': 385, 'resize': 'fit'}}}]},
#         'favorited': False,
#         'retweeted': False,
#         'possibly_sensitive': False,
#         'filter_level': 'low',
#         'lang': 'in'},
#        'quoted_status_permalink': {'url': 'https://t.co/dONgHQEA9G',
#         'expanded': 'https://twitter.com/isusemasaviral/status/1516004095584530435',
#         'display': 'twitter.com/isusemasaviral…'},
#        'is_quote_status': True,
#        'extended_tweet': {'full_text': 'Mohon sedekahkan al-Fatihah kepada sepupu saya ini, Muhammad Firdaus. Allahyarham masih sangat muda. Baik tutur katanya. Beliau kemalangan dalam perjalanan balik dari kerja di Hospital Temerloh. Selamat jalan Angah…',
#         'display_text_range': [0, 215],
#         'entities': {'hashtags': [],
#          'urls': [],
#          'user_mentions': [],
#          'symbols': []}},
#        'quote_count': 59,
#        'reply_count': 83,
#        'retweet_count': 3771,
#        'favorite_count': 4206,
#        'entities': {'hashtags': [],
#         'urls': [{'url': 'https://t.co/0PWDpUGbPC',
#           'expanded_url': 'https://twitter.com/i/web/status/1516136632436477953',
#           'display_url': 'twitter.com/i/web/status/1…',
#           'indices': [117, 140]}],
#         'user_mentions': [],
#         'symbols': []},
#        'favorited': False,
#        'retweeted': False,
#        'filter_level': 'low',
#        'lang': 'in'},
#       'quoted_status_id': 1516004095584530435,
#       'quoted_status_id_str': '1516004095584530435',
#       'quoted_status': {'created_at': 'Mon Apr 18 10:41:57 +0000 2022',
#        'id': 1516004095584530435,
#        'id_str': '1516004095584530435',
#        'text': 'Walao weh. giler uncle ni msuk simpang secara melulu mcmtu jee sampai rider terpelanting. naya nyawa org weh. https://t.co/m6G4LFYOHL',
#        'display_text_range': [0, 109],
#        'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#        'truncated': False,
#        'in_reply_to_status_id': None,
#        'in_reply_to_status_id_str': None,
#        'in_reply_to_user_id': None,
#        'in_reply_to_user_id_str': None,
#        'in_reply_to_screen_name': None,
#        'user': {'id': 2905716522,
#         'id_str': '2905716522',
#         'name': 'ISU SEMASA VIRAL',
#         'screen_name': 'isusemasaviral',
#         'location': 'Kuala Lumpur City',
#         'url': None,
#         'description': None,
#         'translator_type': 'none',
#         'protected': False,
#         'verified': False,
#         'followers_count': 27161,
#         'friends_count': 3,
#         'listed_count': 24,
#         'favourites_count': 70,
#         'statuses_count': 11758,
#         'created_at': 'Fri Nov 21 05:37:21 +0000 2014',
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'profile_background_color': 'C0DEED',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_tile': False,
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1506279361301082115/rj9vuCGJ_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1506279361301082115/rj9vuCGJ_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2905716522/1647920971',
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'withheld_in_countries': []},
#        'geo': None,
#        'coordinates': None,
#        'place': None,
#        'contributors': None,
#        'is_quote_status': False,
#        'quote_count': 601,
#        'reply_count': 146,
#        'retweet_count': 3651,
#        'favorite_count': 4255,
#        'entities': {'hashtags': [],
#         'urls': [],
#         'user_mentions': [],
#         'symbols': [],
#         'media': [{'id': 1516004042249740288,
#           'id_str': '1516004042249740288',
#           'indices': [110, 133],
#           'additional_media_info': {'monetizable': False},
#           'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#           'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#           'url': 'https://t.co/m6G4LFYOHL',
#           'display_url': 'pic.twitter.com/m6G4LFYOHL',
#           'expanded_url': 'https://twitter.com/isusemasaviral/status/1516004095584530435/video/1',
#           'type': 'photo',
#           'sizes': {'large': {'w': 1272, 'h': 720, 'resize': 'fit'},
#            'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'medium': {'w': 1200, 'h': 679, 'resize': 'fit'},
#            'small': {'w': 680, 'h': 385, 'resize': 'fit'}}}]},
#        'extended_entities': {'media': [{'id': 1516004042249740288,
#           'id_str': '1516004042249740288',
#           'indices': [110, 133],
#           'additional_media_info': {'monetizable': False},
#           'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#           'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1516004042249740288/pu/img/Y3Nku2UTYiUAxZ7a.jpg',
#           'url': 'https://t.co/m6G4LFYOHL',
#           'display_url': 'pic.twitter.com/m6G4LFYOHL',
#           'expanded_url': 'https://twitter.com/isusemasaviral/status/1516004095584530435/video/1',
#           'type': 'video',
#           'video_info': {'aspect_ratio': [53, 30],
#            'duration_millis': 29601,
#            'variants': [{'content_type': 'application/x-mpegURL',
#              'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/pl/nQhTA_ESF2IV1-tk.m3u8?tag=12&container=fmp4'},
#             {'bitrate': 256000,
#              'content_type': 'video/mp4',
#              'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/476x270/R3PD8Wlv5f_Qia7d.mp4?tag=12'},
#             {'bitrate': 2176000,
#              'content_type': 'video/mp4',
#              'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/1272x720/CF9niosUk6Bwv3dd.mp4?tag=12'},
#             {'bitrate': 832000,
#              'content_type': 'video/mp4',
#              'url': 'https://video.twimg.com/ext_tw_video/1516004042249740288/pu/vid/636x360/Pxqbs7kW_nJmmKTq.mp4?tag=12'}]},
#           'sizes': {'large': {'w': 1272, 'h': 720, 'resize': 'fit'},
#            'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'medium': {'w': 1200, 'h': 679, 'resize': 'fit'},
#            'small': {'w': 680, 'h': 385, 'resize': 'fit'}}}]},
#        'favorited': False,
#        'retweeted': False,
#        'possibly_sensitive': False,
#        'filter_level': 'low',
#        'lang': 'in'},
#       'quoted_status_permalink': {'url': 'https://t.co/dONgHQEA9G',
#        'expanded': 'https://twitter.com/isusemasaviral/status/1516004095584530435',
#        'display': 'twitter.com/isusemasaviral…'},
#       'is_quote_status': True,
#       'quote_count': 0,
#       'reply_count': 0,
#       'retweet_count': 0,
#       'favorite_count': 0,
#       'entities': {'hashtags': [],
#        'urls': [],
#        'user_mentions': [{'screen_name': 'tunfairuz',
#          'name': 'Dewi',
#          'id': 777747875967086592,
#          'id_str': '777747875967086592',
#          'indices': [3, 13]}],
#        'symbols': []},
#       'favorited': False,
#       'retweeted': False,
#       'filter_level': 'low',
#       'lang': 'in',
#       'timestamp_ms': '1650352486361',
#       'ignore_lang': True},
#      'type': 'search'}}]}}

# %%
url = 'https://elasticsearch.malaysiaai.ml/twitter_streaming/_count'
requests.get(url, cookies = cookies).json()
# Out:
# {'count': 696042,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %% [markdown]
# ## News
#
# Simply query https://elasticsearch.malaysiaai.ml/news_v2/_search

# %%
query = {
    'size': 2
}
url = 'https://elasticsearch.malaysiaai.ml/news_v2/_search'
requests.get(url, cookies = cookies, json = query).json()
# Out:
# {'took': 617,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1406, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'news_v2',
#     '_type': '_doc',
#     '_id': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#     '_score': 1.0,
#     '_ignored': ['extractnet.description.keyword',
#      'extractnet.content.keyword'],
#     '_source': {'title': 'Debate between Anwar and Najib on May 12',
#      'media': '',
#      'date': '8 hours ago',
#      'datetime': '2022-04-17T15:17:40.338691',
#      'desc': 'KUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar \nIbrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held \non May...',
#      'link': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#      'img': '...',
#      'extractnet': {'content': 'Representative of Datuk Seri Anwar Ibrahim, Fahmi Fadzil and representative of Datuk Seri Najib Razak, Isham Jalil speaks during a press conference on the Najib vs Anwar debate, Kuala Lumpur April 17, 2022. – Malay Mail photo\nKUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar Ibrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held on May 12.\nPKR Communications director Ahmad Fahmi Mohamed Fadzil said it will be held at the Tunku Chancellor’s Hall, Universiti Malaya, here at 9pm and will also be broadcast live through media channels to be announced later.\n“Detailed information on the physical presence will be announced later,” he said at a press conference with Selangor Barisan Nasional (BN) Information chief Isham Jalil here today.\nAhmad Fahmi said the format of the debate between the two political figures would consist of three parts, with the first on problems facing oil and gas company\xa0Sapura Energy Bhd (SEB), whether it should be saved or not.\n“The second is on ‘Malaysia’s Future’ covering economy, politics, governance and the country’s direction and the third is the question and answer session,” he said, adding that the debate is scheduled for two hours.\nMeanwhile, Isham said in compliance with the standard operating procedures on Covid-19, the Dewan Tunku Chancellor could accommodate about 500 people.\n“Outside the hall there is also an area and we will set up tents and big screens to be broadcast to those present at the location because inside the hall there are constraints (invitation capacity),” he said.\nHe said canopies would be set up outside the hall, and those present could watch the debate live on a large screen. – Bernama',
#       'headlines': 'April 17, 2022, Sunday at 2:25 PM',
#       'title': 'Debate between Anwar and Najib on May 12 - Borneo Post Online',
#       'url': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#       'hostname': 'theborneopost.com',
#       'description': "KUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar Ibrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held on May 12. PKR Communications director Ahmad Fahmi Mohamed Fadzil said it will be held at the Tunku Chancellor's Hall, Universiti Malaya, here at 9pm and will also be broadcast live through media channels to be",
#       'sitename': 'Borneo Post Online',
#       'date': '2022-04-17T00:00:00',
#       'categories': ['Nation'],
#       'tags': [],
#       'site_name': 'Borneo Post Online',
#       'rawAuthor': 'BP 3',
#       'authorList': ['BP 3'],
#       'rawDate': '2022-04-17'},
#      'lang': 'en'}},
#    {'_index': 'news_v2',
#     '_type': '_doc',
#     '_id': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#     '_score': 1.0,
#     '_ignored': ['extractnet.description.keyword',
#      'extractnet.content.keyword'],
#     '_source': {'title': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister',
#      'media': '',
#      'date': '3 mins ago',
#      'datetime': None,
#      'desc': "MELAKA, April '17 — No parties have approached the Communications and \nMultimedia Ministry to discuss if a government media platform can be used \nto air the...",
#      'link': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#      'img': '...',
#      'extractnet': {'content': 'Tan Sri Annuar Musa said the debate had nothing to do with the government. — Bernama pic\nInstagram and subscribe to our\nTelegram channel for the latest updates.\nMELAKA,\xa0 April ‘17 — No parties have approached the Communications and Multimedia Ministry to discuss if a government media platform can be used to air the public debate between Datuk Seri Najib Tun Razak and Datuk Seri Anwar Ibrahim on May 12.\nCommunications and Multimedia Minister Tan Sri Annuar Musa said the debate had nothing to do with the government and he considered it a discourse between two individuals.\n“So the government is staying out of this, and I have not been approached by anyone either. I believe it is still at a stage between two individuals,” he told reporters after attending a breaking of fast event with the Melaka community at the DoubleTree By Hilton hotel here today.\nAlso present was Malaysian National News Agency (Bernama acting chief executive officer Roslan Ariffin.\nAnnuar said he only followed the latest developments on the matter because one was the Opposition chief while the other was a government backbencher.\nAnnuar, however, did not rule out the use of social media or any of the latest digital platforms to air the debate.\n“Live (streaming) is common with technology nowadays and perhaps there are also television networks that may want to provide a platform as well.\n“Anyway, that’s something (to be decided) for later. We cannot say maybe either as saying that is akin to committing (for the debate to be aired via a government platform). I will consider this a normal debate between two individuals,” he said.\nPKR Communications director Ahmad Fahmi Mohamed Fadzil announced earlier today that the debate will take place at 9 pm on May 12, and will, among others, discuss the Sapura Energy Bhd (SEB) issue and ‘Malaysia’s Future’ covering economy, politics, governance and the country’s direction.\nTogether with him at the media conference held here was Selangor Barisan Nasional (BN) Information chief Isham Jalil.\nSo far, the debate can be viewed via media channels to be announced later or watched live at Dewan Tunku Canselor, Universiti Malaya here.\nEarlier, Annuar paid a courtesy call on Yang Dipertua Negeri of Melaka Tun Mohd Ali Mohd Rustam at his office at Seri Negeri and briefed him on efforts being taken by the ministry in Melaka.\n“I also informed that the National Journalists Day will be held in Melaka this year,” Annuar said in a Twitter post tonight. —\xa0Bernama',
#       'headlines': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister',
#       'title': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister | Malay Mail',
#       'url': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#       'hostname': 'malaymail.com',
#       'description': 'MELAKA,&nbsp; April ‘17 — No parties have approached the Communications and Multimedia Ministry to discuss if a government media platform can be used to air the public debate between Datuk Seri Najib Tun Razak and Datuk Seri Anwar Ibrahim on May 12. Communications and Multimedia Minister Tan...',
#       'sitename': 'Malay Mail',
#       'date': '2022-04-17T00:00:00',
#       'categories': ['Malaysia'],
#       'tags': ['annuar musa', ' anwar ibrahim najib razak debate'],
#       'site_name': '@malaymail',
#       'video': 'https://www.googletagmanager.com/ns.html?id=GTM-5LC3K8F',
#       'rawAuthor': 'Malay Mail',
#       'authorList': ['Malay Mail'],
#       'rawDate': '2022-04-17'},
#      'lang': 'en',
#      'lang_deep': 'eng'}}]}}

# %%
url = 'https://elasticsearch.malaysiaai.ml/news_v2/_count'
requests.get(url, cookies = cookies).json()
# Out:
# {'count': 1406,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %% [markdown]
# ## simple alerts
#
# We also deployed alerts at Grafana Cloud using PromQL, https://huseinzol05.grafana.net/d/BHvsNRwnz/crawler-alerts?orgId=1
#
# You can check [prometheus.yaml](https://github.com/malaysia-ai/alerts/blob/main/prometheus.yaml), again, you need to be part of Malaysia-AI to access it.
#
# Feel free to contact husein.zol05@gmail.com to get access for Grafana Cloud.

# %% [markdown]
# ![](artifacts/alert.png)

# %% [markdown]
# Any graphs goes down below than 1, it will send an alert at Discord,
#
# ![](artifacts/alert-discord.png)
