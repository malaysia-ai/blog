# %% [markdown]
# # Twitter and local news data in Malaysia-AI Elasticsearch

# %% [markdown]
# As you know, Malaysia-AI got a cloud ElasticSearch, protected by Github Auth at https://elasticsearch.malaysiaai.ml/, and recently we deployed Tweepy streaming and local news crawler at https://github.com/malaysia-ai/crawlers. If you are member of Malaysia-AI, you should able to access that repository.

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search
from pycookiecheat import chrome_cookies
import requests

# %% [markdown]
# ## ElasticSearch
#
# To access ElasticSearch from anywhere,
#
# 1. Install dependencies,
#
# ```bash
# pip3 install requests pycookiecheat elasticsearch elasticsearch-dsl
# ```
#
# 2. You need to login https://elasticsearch.malaysiaai.ml using your Chrome.
#
# 3. Get the cookies.

# %%
url = 'https://elasticsearch.malaysiaai.ml'
cookies = chrome_cookies(url)

# %%
requests.get(url, cookies = cookies).json()
# Out:
# {'name': 'huseincomel-desktop',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'WLWwNUhcTAaU7BGpsKwNkA',
#  'version': {'number': '7.17.0',
#   'build_flavor': 'default',
#   'build_type': 'deb',
#   'build_hash': 'bee86328705acaa9a6daede7140defd4d9ec56bd',
#   'build_date': '2022-01-28T08:36:04.875279988Z',
#   'build_snapshot': False,
#   'lucene_version': '8.11.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %% [markdown]
# If you are using https://jupyterhub.malaysiaai.ml/, ElasticSearch available at http://localhost:9200

# %% [markdown]
# ## Twitter
#
# Simply query https://elasticsearch.malaysiaai.ml/twitter_streaming/_search

# %%
query = {
    'size': 2
}
url = 'https://elasticsearch.malaysiaai.ml/twitter_streaming/_search'
requests.get(url, cookies = cookies, json = query).json()
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'twitter_streaming',
#     '_type': '_doc',
#     '_id': '8RHINoABg_n2UR6_b-gj',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-04-17T09:08:21',
#      'datetime_gmt8': '2022-04-17T17:08:21',
#      'data_text': 'seokjin got shy after hobi praising hin https://t.co/MQSa0oGJnW',
#      'body': 'RT @jinniesarchives: seokjin got shy after hobi praising hin https://t.co/MQSa0oGJnW',
#      'screen_name': 'ultskivecart',
#      'followers_count': 123,
#      'friends_count': 85,
#      'listed_count': 0,
#      'favourites_count': 2846,
#      'statuses_count': 2181,
#      'quoted_status_text': 'NULL',
#      'lang': 'in',
#      'retweet': 'true',
#      'retweet_text': 'seokjin got shy after hobi praising hin https://t.co/MQSa0oGJnW',
#      'retweet_text_full': 'NULL',
#      'retweet_count': 0,
#      'retweet_detail': {'retweet_count': 7278,
#       'quote_count': 552,
#       'favorite_count': 22726,
#       'reply_count': 30,
#       'id_str': '1515551647535353861',
#       'followers_count': 45600,
#       'friends_count': 66,
#       'listed_count': 384,
#       'favourites_count': 32013,
#       'statuses_count': 36876,
#       'screen_name': 'jinniesarchives'},
#      'quote_count': 0,
#      'favorite_count': 0,
#      'reply_count': 0,
#      'id_str': '1515618155108143106',
#      'tweet': {'created_at': 'Sun Apr 17 09:08:21 +0000 2022',
#       'id': 1515618155108143106,
#       'id_str': '1515618155108143106',
#       'text': 'RT @jinniesarchives: seokjin got shy after hobi praising hin https://t.co/MQSa0oGJnW',
#       'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#       'truncated': False,
#       'in_reply_to_status_id': None,
#       'in_reply_to_status_id_str': None,
#       'in_reply_to_user_id': None,
#       'in_reply_to_user_id_str': None,
#       'in_reply_to_screen_name': None,
#       'user': {'id': 1480866186632249344,
#        'id_str': '1480866186632249344',
#        'name': 'ree | ia 📚',
#        'screen_name': 'ultskivecart',
#        'location': "— always, bangtan. they '01",
#        'url': None,
#        'description': '🛒 bns acc — slow spark collector ! 💿',
#        'translator_type': 'none',
#        'protected': False,
#        'verified': False,
#        'followers_count': 123,
#        'friends_count': 85,
#        'listed_count': 0,
#        'favourites_count': 2846,
#        'statuses_count': 2181,
#        'created_at': 'Tue Jan 11 11:36:43 +0000 2022',
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'profile_background_color': 'F5F8FA',
#        'profile_background_image_url': '',
#        'profile_background_image_url_https': '',
#        'profile_background_tile': False,
#        'profile_link_color': '1DA1F2',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1513857536117854210/wdYnueXh_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1513857536117854210/wdYnueXh_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1480866186632249344/1649766943',
#        'default_profile': True,
#        'default_profile_image': False,
#        'following': None,
#        'follow_request_sent': None,
#        'notifications': None,
#        'withheld_in_countries': []},
#       'geo': None,
#       'coordinates': None,
#       'place': None,
#       'contributors': None,
#       'retweeted_status': {'created_at': 'Sun Apr 17 04:44:05 +0000 2022',
#        'id': 1515551647535353861,
#        'id_str': '1515551647535353861',
#        'text': 'seokjin got shy after hobi praising hin https://t.co/MQSa0oGJnW',
#        'display_text_range': [0, 39],
#        'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        'truncated': False,
#        'in_reply_to_status_id': None,
#        'in_reply_to_status_id_str': None,
#        'in_reply_to_user_id': None,
#        'in_reply_to_user_id_str': None,
#        'in_reply_to_screen_name': None,
#        'user': {'id': 1390423860877533186,
#         'id_str': '1390423860877533186',
#         'name': 'ً',
#         'screen_name': 'jinniesarchives',
#         'location': '2 admins. turn notifs on🔔',
#         'url': 'https://share.stationhead.com/jinniesarchives',
#         'description': 'for JIN #진 ♡ | repost with credit ⭕️',
#         'translator_type': 'none',
#         'protected': False,
#         'verified': False,
#         'followers_count': 45600,
#         'friends_count': 66,
#         'listed_count': 384,
#         'favourites_count': 32013,
#         'statuses_count': 36876,
#         'created_at': 'Thu May 06 21:51:09 +0000 2021',
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'profile_background_color': 'F5F8FA',
#         'profile_background_image_url': '',
#         'profile_background_image_url_https': '',
#         'profile_background_tile': False,
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1515593576637669381/K089XuBD_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1515593576637669381/K089XuBD_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1390423860877533186/1650180642',
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'withheld_in_countries': []},
#        'geo': None,
#        'coordinates': None,
#        'place': None,
#        'contributors': None,
#        'is_quote_status': False,
#        'quote_count': 552,
#        'reply_count': 30,
#        'retweet_count': 7278,
#        'favorite_count': 22726,
#        'entities': {'hashtags': [],
#         'urls': [],
#         'user_mentions': [],
#         'symbols': [],
#         'media': [{'id': 1515551640165953538,
#           'id_str': '1515551640165953538',
#           'indices': [40, 63],
#           'media_url': 'http://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#           'url': 'https://t.co/MQSa0oGJnW',
#           'display_url': 'pic.twitter.com/MQSa0oGJnW',
#           'expanded_url': 'https://twitter.com/jinniesarchives/status/1515551647535353861/photo/1',
#           'type': 'photo',
#           'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#            'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#            'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}}}]},
#        'extended_entities': {'media': [{'id': 1515551640165953538,
#           'id_str': '1515551640165953538',
#           'indices': [40, 63],
#           'media_url': 'http://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#           'url': 'https://t.co/MQSa0oGJnW',
#           'display_url': 'pic.twitter.com/MQSa0oGJnW',
#           'expanded_url': 'https://twitter.com/jinniesarchives/status/1515551647535353861/photo/1',
#           'type': 'photo',
#           'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#            'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#            'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}}}]},
#        'favorited': False,
#        'retweeted': False,
#        'possibly_sensitive': False,
#        'filter_level': 'low',
#        'lang': 'in'},
#       'is_quote_status': False,
#       'quote_count': 0,
#       'reply_count': 0,
#       'retweet_count': 0,
#       'favorite_count': 0,
#       'entities': {'hashtags': [],
#        'urls': [],
#        'user_mentions': [{'screen_name': 'jinniesarchives',
#          'name': 'ً',
#          'id': 1390423860877533186,
#          'id_str': '1390423860877533186',
#          'indices': [3, 19]}],
#        'symbols': [],
#        'media': [{'id': 1515551640165953538,
#          'id_str': '1515551640165953538',
#          'indices': [61, 84],
#          'media_url': 'http://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#          'url': 'https://t.co/MQSa0oGJnW',
#          'display_url': 'pic.twitter.com/MQSa0oGJnW',
#          'expanded_url': 'https://twitter.com/jinniesarchives/status/1515551647535353861/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#           'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#           'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}},
#          'source_status_id': 1515551647535353861,
#          'source_status_id_str': '1515551647535353861',
#          'source_user_id': 1390423860877533186,
#          'source_user_id_str': '1390423860877533186'}]},
#       'extended_entities': {'media': [{'id': 1515551640165953538,
#          'id_str': '1515551640165953538',
#          'indices': [61, 84],
#          'media_url': 'http://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQhSL97aMAIWl_q.jpg',
#          'url': 'https://t.co/MQSa0oGJnW',
#          'display_url': 'pic.twitter.com/MQSa0oGJnW',
#          'expanded_url': 'https://twitter.com/jinniesarchives/status/1515551647535353861/photo/1',
#          'type': 'photo',
#          'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#           'large': {'w': 2048, 'h': 2048, 'resize': 'fit'},
#           'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'}},
#          'source_status_id': 1515551647535353861,
#          'source_status_id_str': '1515551647535353861',
#          'source_user_id': 1390423860877533186,
#          'source_user_id_str': '1390423860877533186'}]},
#       'favorited': False,
#       'retweeted': False,
#       'possibly_sensitive': False,
#       'filter_level': 'low',
#       'lang': 'in',
#       'timestamp_ms': '1650186501658',
#       'ignore_lang': True},
#      'type': 'search'}},
#    {'_index': 'twitter_streaming',
#     '_type': '_doc',
#     '_id': '8hHINoABg_n2UR6_cugR',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-04-17T09:08:58',
#      'datetime_gmt8': '2022-04-17T17:08:58',
#      'data_text': ' Anak lanang semata wayang kemarin abis ultah ke-2 tahun  https://t.co/PS07w5aZ6K',
#      'body': 'RT @kochengfess:  Anak lanang semata wayang kemarin abis ultah ke-2 tahun  https://t.co/PS07w5aZ6K',
#      'screen_name': 'so_nya30',
#      'followers_count': 117,
#      'friends_count': 359,
#      'listed_count': 0,
#      'favourites_count': 1925,
#      'statuses_count': 70574,
#      'quoted_status_text': 'NULL',
#      'lang': 'in',
#      'retweet': 'true',
#      'retweet_text': ' Anak lanang semata wayang kemarin abis ultah ke-2 tahun  https://t.co/PS07w5aZ6K',
#      'retweet_text_full': 'NULL',
#      'retweet_count': 0,
#      'retweet_detail': {'retweet_count': 3,
#       'quote_count': 0,
#       'favorite_count': 51,
#       'reply_count': 0,
#       'id_str': '1515607246541299712',
#       'followers_count': 287359,
#       'friends_count': 5478,
#       'listed_count': 1411,
#       'favourites_count': 27,
#       'statuses_count': 314175,
#       'screen_name': 'kochengfess'},
#      'quote_count': 0,
#      'favorite_count': 0,
#      'reply_count': 0,
#      'id_str': '1515618307553959936',
#      'tweet': {'created_at': 'Sun Apr 17 09:08:58 +0000 2022',
#       'id': 1515618307553959936,
#       'id_str': '1515618307553959936',
#       'text': 'RT @kochengfess: 🐈 Anak lanang semata wayang kemarin abis ultah ke-2 tahun 🥳 https://t.co/PS07w5aZ6K',
#       'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#       'truncated': False,
#       'in_reply_to_status_id': None,
#       'in_reply_to_status_id_str': None,
#       'in_reply_to_user_id': None,
#       'in_reply_to_user_id_str': None,
#       'in_reply_to_screen_name': None,
#       'user': {'id': 810661646389514240,
#        'id_str': '810661646389514240',
#        'name': 'so',
#        'screen_name': 'so_nya30',
#        'location': 'ANTAH BERANTAH',
#        'url': None,
#        'description': '👩\u200d💻',
#        'translator_type': 'none',
#        'protected': False,
#        'verified': False,
#        'followers_count': 117,
#        'friends_count': 359,
#        'listed_count': 0,
#        'favourites_count': 1925,
#        'statuses_count': 70574,
#        'created_at': 'Mon Dec 19 01:42:52 +0000 2016',
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'profile_background_color': 'F5F8FA',
#        'profile_background_image_url': '',
#        'profile_background_image_url_https': '',
#        'profile_background_tile': False,
#        'profile_link_color': '1DA1F2',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1347849020102725633/XF2MQEYN_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1347849020102725633/XF2MQEYN_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/810661646389514240/1527687024',
#        'default_profile': True,
#        'default_profile_image': False,
#        'following': None,
#        'follow_request_sent': None,
#        'notifications': None,
#        'withheld_in_countries': []},
#       'geo': None,
#       'coordinates': None,
#       'place': None,
#       'contributors': None,
#       'retweeted_status': {'created_at': 'Sun Apr 17 08:25:00 +0000 2022',
#        'id': 1515607246541299712,
#        'id_str': '1515607246541299712',
#        'text': '🐈 Anak lanang semata wayang kemarin abis ultah ke-2 tahun 🥳 https://t.co/PS07w5aZ6K',
#        'display_text_range': [0, 59],
#        'source': '<a href="https://twitter.com/kochengfess" rel="nofollow">KochengFess SP</a>',
#        'truncated': False,
#        'in_reply_to_status_id': None,
#        'in_reply_to_status_id_str': None,
#        'in_reply_to_user_id': None,
#        'in_reply_to_user_id_str': None,
#        'in_reply_to_screen_name': None,
#        'user': {'id': 624785829,
#         'id_str': '624785829',
#         'name': 'OPEN DM 🕌',
#         'screen_name': 'kochengfess',
#         'location': 'Indonesia',
#         'url': 'https://twitter.com/yourpetsfess',
#         'description': 'Kirim menfess / rules / syarat? DM us with /mymenu (pakai garis miring)\n\n👇👇👇\n\nTrigger : kcg!\n\n•Please DM 👉 @pakpulici100 (Business, Report & ©️ Issues) 🙏😽',
#         'translator_type': 'none',
#         'protected': False,
#         'verified': False,
#         'followers_count': 287359,
#         'friends_count': 5478,
#         'listed_count': 1411,
#         'favourites_count': 27,
#         'statuses_count': 314175,
#         'created_at': 'Mon Jul 02 14:24:56 +0000 2012',
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'profile_background_color': 'B2DFDA',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#         'profile_background_tile': False,
#         'profile_link_color': '93A644',
#         'profile_sidebar_border_color': 'EEEEEE',
#         'profile_sidebar_fill_color': 'FFFFFF',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1464523432352124930/Eux7YQLa_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1464523432352124930/Eux7YQLa_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/624785829/1629792185',
#         'default_profile': False,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'withheld_in_countries': []},
#        'geo': None,
#        'coordinates': None,
#        'place': None,
#        'contributors': None,
#        'is_quote_status': False,
#        'quote_count': 0,
#        'reply_count': 0,
#        'retweet_count': 3,
#        'favorite_count': 51,
#        'entities': {'hashtags': [],
#         'urls': [],
#         'user_mentions': [],
#         'symbols': [],
#         'media': [{'id': 1515606509354246145,
#           'id_str': '1515606509354246145',
#           'indices': [60, 83],
#           'media_url': 'http://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#           'url': 'https://t.co/PS07w5aZ6K',
#           'display_url': 'pic.twitter.com/PS07w5aZ6K',
#           'expanded_url': 'https://twitter.com/kochengfess/status/1515607246541299712/photo/1',
#           'type': 'photo',
#           'sizes': {'small': {'w': 546, 'h': 680, 'resize': 'fit'},
#            'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'large': {'w': 1440, 'h': 1794, 'resize': 'fit'},
#            'medium': {'w': 963, 'h': 1200, 'resize': 'fit'}}}]},
#        'extended_entities': {'media': [{'id': 1515606509354246145,
#           'id_str': '1515606509354246145',
#           'indices': [60, 83],
#           'media_url': 'http://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#           'media_url_https': 'https://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#           'url': 'https://t.co/PS07w5aZ6K',
#           'display_url': 'pic.twitter.com/PS07w5aZ6K',
#           'expanded_url': 'https://twitter.com/kochengfess/status/1515607246541299712/photo/1',
#           'type': 'photo',
#           'sizes': {'small': {'w': 546, 'h': 680, 'resize': 'fit'},
#            'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#            'large': {'w': 1440, 'h': 1794, 'resize': 'fit'},
#            'medium': {'w': 963, 'h': 1200, 'resize': 'fit'}}}]},
#        'favorited': False,
#        'retweeted': False,
#        'possibly_sensitive': False,
#        'filter_level': 'low',
#        'lang': 'in'},
#       'is_quote_status': False,
#       'quote_count': 0,
#       'reply_count': 0,
#       'retweet_count': 0,
#       'favorite_count': 0,
#       'entities': {'hashtags': [],
#        'urls': [],
#        'user_mentions': [{'screen_name': 'kochengfess',
#          'name': 'OPEN DM 🕌',
#          'id': 624785829,
#          'id_str': '624785829',
#          'indices': [3, 15]}],
#        'symbols': [],
#        'media': [{'id': 1515606509354246145,
#          'id_str': '1515606509354246145',
#          'indices': [77, 100],
#          'media_url': 'http://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#          'url': 'https://t.co/PS07w5aZ6K',
#          'display_url': 'pic.twitter.com/PS07w5aZ6K',
#          'expanded_url': 'https://twitter.com/kochengfess/status/1515607246541299712/photo/1',
#          'type': 'photo',
#          'sizes': {'small': {'w': 546, 'h': 680, 'resize': 'fit'},
#           'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'large': {'w': 1440, 'h': 1794, 'resize': 'fit'},
#           'medium': {'w': 963, 'h': 1200, 'resize': 'fit'}},
#          'source_status_id': 1515607246541299712,
#          'source_status_id_str': '1515607246541299712',
#          'source_user_id': 624785829,
#          'source_user_id_str': '624785829'}]},
#       'extended_entities': {'media': [{'id': 1515606509354246145,
#          'id_str': '1515606509354246145',
#          'indices': [77, 100],
#          'media_url': 'http://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#          'media_url_https': 'https://pbs.twimg.com/media/FQiEFxlUYAE2DxW.jpg',
#          'url': 'https://t.co/PS07w5aZ6K',
#          'display_url': 'pic.twitter.com/PS07w5aZ6K',
#          'expanded_url': 'https://twitter.com/kochengfess/status/1515607246541299712/photo/1',
#          'type': 'photo',
#          'sizes': {'small': {'w': 546, 'h': 680, 'resize': 'fit'},
#           'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#           'large': {'w': 1440, 'h': 1794, 'resize': 'fit'},
#           'medium': {'w': 963, 'h': 1200, 'resize': 'fit'}},
#          'source_status_id': 1515607246541299712,
#          'source_status_id_str': '1515607246541299712',
#          'source_user_id': 624785829,
#          'source_user_id_str': '624785829'}]},
#       'favorited': False,
#       'retweeted': False,
#       'possibly_sensitive': False,
#       'filter_level': 'low',
#       'lang': 'in',
#       'timestamp_ms': '1650186538004',
#       'ignore_lang': True},
#      'type': 'search'}}]}}

# %%
url = 'https://elasticsearch.malaysiaai.ml/twitter_streaming/_count'
requests.get(url, cookies = cookies).json()
# Out:
# {'count': 172000,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %% [markdown]
# ## News
#
# Simply query https://elasticsearch.malaysiaai.ml/news_v2/_search

# %%
query = {
    'size': 2
}
url = 'https://elasticsearch.malaysiaai.ml/news_v2/_search'
requests.get(url, cookies = cookies, json = query).json()
# Out:
# {'took': 303,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 409, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'news_v2',
#     '_type': '_doc',
#     '_id': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#     '_score': 1.0,
#     '_ignored': ['extractnet.description.keyword',
#      'extractnet.content.keyword'],
#     '_source': {'title': 'Debate between Anwar and Najib on May 12',
#      'media': '',
#      'date': '8 hours ago',
#      'datetime': '2022-04-17T15:17:40.338691',
#      'desc': 'KUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar \nIbrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held \non May...',
#      'link': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#      'img': '...',
#      'extractnet': {'content': 'Representative of Datuk Seri Anwar Ibrahim, Fahmi Fadzil and representative of Datuk Seri Najib Razak, Isham Jalil speaks during a press conference on the Najib vs Anwar debate, Kuala Lumpur April 17, 2022. – Malay Mail photo\nKUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar Ibrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held on May 12.\nPKR Communications director Ahmad Fahmi Mohamed Fadzil said it will be held at the Tunku Chancellor’s Hall, Universiti Malaya, here at 9pm and will also be broadcast live through media channels to be announced later.\n“Detailed information on the physical presence will be announced later,” he said at a press conference with Selangor Barisan Nasional (BN) Information chief Isham Jalil here today.\nAhmad Fahmi said the format of the debate between the two political figures would consist of three parts, with the first on problems facing oil and gas company\xa0Sapura Energy Bhd (SEB), whether it should be saved or not.\n“The second is on ‘Malaysia’s Future’ covering economy, politics, governance and the country’s direction and the third is the question and answer session,” he said, adding that the debate is scheduled for two hours.\nMeanwhile, Isham said in compliance with the standard operating procedures on Covid-19, the Dewan Tunku Chancellor could accommodate about 500 people.\n“Outside the hall there is also an area and we will set up tents and big screens to be broadcast to those present at the location because inside the hall there are constraints (invitation capacity),” he said.\nHe said canopies would be set up outside the hall, and those present could watch the debate live on a large screen. – Bernama',
#       'headlines': 'April 17, 2022, Sunday at 2:25 PM',
#       'title': 'Debate between Anwar and Najib on May 12 - Borneo Post Online',
#       'url': 'https://www.theborneopost.com/2022/04/17/debate-between-anwar-and-najib-on-may-12/',
#       'hostname': 'theborneopost.com',
#       'description': "KUALA LUMPUR (April 17): The debate between PKR president Datuk Seri Anwar Ibrahim and former Prime Minister Datuk Seri Najib Tun Razak will be held on May 12. PKR Communications director Ahmad Fahmi Mohamed Fadzil said it will be held at the Tunku Chancellor's Hall, Universiti Malaya, here at 9pm and will also be broadcast live through media channels to be",
#       'sitename': 'Borneo Post Online',
#       'date': '2022-04-17T00:00:00',
#       'categories': ['Nation'],
#       'tags': [],
#       'site_name': 'Borneo Post Online',
#       'rawAuthor': 'BP 3',
#       'authorList': ['BP 3'],
#       'rawDate': '2022-04-17'},
#      'lang': 'en'}},
#    {'_index': 'news_v2',
#     '_type': '_doc',
#     '_id': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#     '_score': 1.0,
#     '_ignored': ['extractnet.description.keyword',
#      'extractnet.content.keyword'],
#     '_source': {'title': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister',
#      'media': '',
#      'date': '3 mins ago',
#      'datetime': None,
#      'desc': "MELAKA, April '17 — No parties have approached the Communications and \nMultimedia Ministry to discuss if a government media platform can be used \nto air the...",
#      'link': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#      'img': '...',
#      'extractnet': {'content': 'Tan Sri Annuar Musa said the debate had nothing to do with the government. — Bernama pic\nInstagram and subscribe to our\nTelegram channel for the latest updates.\nMELAKA,\xa0 April ‘17 — No parties have approached the Communications and Multimedia Ministry to discuss if a government media platform can be used to air the public debate between Datuk Seri Najib Tun Razak and Datuk Seri Anwar Ibrahim on May 12.\nCommunications and Multimedia Minister Tan Sri Annuar Musa said the debate had nothing to do with the government and he considered it a discourse between two individuals.\n“So the government is staying out of this, and I have not been approached by anyone either. I believe it is still at a stage between two individuals,” he told reporters after attending a breaking of fast event with the Melaka community at the DoubleTree By Hilton hotel here today.\nAlso present was Malaysian National News Agency (Bernama acting chief executive officer Roslan Ariffin.\nAnnuar said he only followed the latest developments on the matter because one was the Opposition chief while the other was a government backbencher.\nAnnuar, however, did not rule out the use of social media or any of the latest digital platforms to air the debate.\n“Live (streaming) is common with technology nowadays and perhaps there are also television networks that may want to provide a platform as well.\n“Anyway, that’s something (to be decided) for later. We cannot say maybe either as saying that is akin to committing (for the debate to be aired via a government platform). I will consider this a normal debate between two individuals,” he said.\nPKR Communications director Ahmad Fahmi Mohamed Fadzil announced earlier today that the debate will take place at 9 pm on May 12, and will, among others, discuss the Sapura Energy Bhd (SEB) issue and ‘Malaysia’s Future’ covering economy, politics, governance and the country’s direction.\nTogether with him at the media conference held here was Selangor Barisan Nasional (BN) Information chief Isham Jalil.\nSo far, the debate can be viewed via media channels to be announced later or watched live at Dewan Tunku Canselor, Universiti Malaya here.\nEarlier, Annuar paid a courtesy call on Yang Dipertua Negeri of Melaka Tun Mohd Ali Mohd Rustam at his office at Seri Negeri and briefed him on efforts being taken by the ministry in Melaka.\n“I also informed that the National Journalists Day will be held in Melaka this year,” Annuar said in a Twitter post tonight. —\xa0Bernama',
#       'headlines': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister',
#       'title': 'Najib-Anwar debate: Communications Ministry not approached for use of govt media platform, says minister | Malay Mail',
#       'url': 'https://www.malaymail.com/news/malaysia/2022/04/17/najib-anwar-debate-communications-ministry-not-approached-for-use-of-govt-m/2054100',
#       'hostname': 'malaymail.com',
#       'description': 'MELAKA,&nbsp; April ‘17 — No parties have approached the Communications and Multimedia Ministry to discuss if a government media platform can be used to air the public debate between Datuk Seri Najib Tun Razak and Datuk Seri Anwar Ibrahim on May 12. Communications and Multimedia Minister Tan...',
#       'sitename': 'Malay Mail',
#       'date': '2022-04-17T00:00:00',
#       'categories': ['Malaysia'],
#       'tags': ['annuar musa', ' anwar ibrahim najib razak debate'],
#       'site_name': '@malaymail',
#       'video': 'https://www.googletagmanager.com/ns.html?id=GTM-5LC3K8F',
#       'rawAuthor': 'Malay Mail',
#       'authorList': ['Malay Mail'],
#       'rawDate': '2022-04-17'},
#      'lang': 'en',
#      'lang_deep': 'eng'}}]}}

# %%
url = 'https://elasticsearch.malaysiaai.ml/news_v2/_count'
requests.get(url, cookies = cookies).json()
# Out:
# {'count': 408,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}}

# %% [markdown]
# ## simple alerts
#
# We also deployed alerts at Grafana Cloud using PromQL, https://huseinzol05.grafana.net/d/BHvsNRwnz/crawler-alerts?orgId=1
#
# You can check [prometheus.yaml](https://github.com/malaysia-ai/alerts/blob/main/prometheus.yaml).
#
# Feel free to contact husein.zol05@gmail.com to get access for Grafana Cloud.

# %% [markdown]
# ![](artifacts/alert.png)

# %% [markdown]
# Any graphs goes down below than 1, it will send an alert at Discord,
#
# ![](artifacts/alert-discord.png)
